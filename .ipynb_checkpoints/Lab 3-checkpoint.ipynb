# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py
import scipy
from PIL import Image
from scipy import ndimage
import pandas as pd

# %%
df = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')

y = df['diagnosis']

df.head(5)
# Out:
#         id_code  diagnosis
# 0  000c1434d8d7          2
# 1  001639a390f0          4
# 2  0024cdab0c1e          1
# 3  002c21358ce6          0
# 4  005b95c28852          0

# %%
img = cv2.imread('train_images/000c1434d8d7.png'.format(f))
img = cv2.resize(img, (200, 200), interpolation = cv2.INTER_CUBIC)
plt.imshow(img)

# %%
n_data = 300
size_pic = 64
X_shape = size_pic*size_pic*3

y = y[:n_data]

x = []
for index, i in enumerate(df[:n_data].values):
    img = cv2.imread('train_images/{}.png'.format(f))
    img = cv2.resize(img, (size_pic, size_pic), interpolation = cv2.INTER_CUBIC)
    x.append(img.flatten()/255)
    
x_test = []
for index, i in enumerate(df_test[:n_data].values):
    img = cv2.imread('train_images/{}.png'.format(f))
    img = cv2.resize(img, (size_pic, size_pic), interpolation = cv2.INTER_CUBIC)
    x_test.append(img.flatten()/255)

# %%
y_n = lambda x: 1 if x > 0 else 0

y = np.array([y_n(i) for i in y])

# %%
y = np.full((1,n_data),y)

# %%
x = np.full((n_data, len(x[0])),x)
x_test = np.full((n_data, len(x_test[0])),x_test)

# %%
x = x.reshape(x.shape[0],-1).T

# %%
x_test = x_test.reshape(x_test.shape[0],-1).T

# %%
def sigmoid(z):
    s = 1/(1 + np.exp(-z))
    return s

# %%
def init_zeroed(dim):
    w = np.zeros(shape=(dim,1))
    b = 0
    
    assert(w.shape == (dim,1))
    assert(isinstance(b,float) or isinstance(b,int))

    return w, b

# %%
def propagate(w, b, X, Y):
    m = X.shape[1]
    
    A = sigmoid(np.dot(w.T, X) + b)
    cost = (-1/m) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1-A)))
    
    dw = (1/m) * np.dot(X, (A-Y).T)
    db = (1/m) * np.sum(A-Y)
    
    assert(dw.shape == w.shape)
    assert(db.dtype == float)
    cost = np.squeeze(cost)
    assert(cost.shape == ())
    
    grads = {'dw':dw, 'db': db}
    
    return grads, cost

# %%
def optimize(w, b, X, Y, num_iter, l_rate):
    costs = []
    
    for i in range(num_iter):
        
        grads, cost = propagate(w, b, X, Y)
        
        dw = grads['dw']
        db = grads['db']
        
        w = w - l_rate * dw
        b = b - l_rate * db
        
        if i % 100 == 0:
            costs.append(cost)
        
    params = {'w':w, 'b':b}
    grads  = {'dw':dw, 'db':db}
    
    return params, grads, costs

# %%
def predict(w, b, X):
    m = X.shape[1]
    Y_prediction = np.zeros((1, m))
    w.reshape(X.shape[0],1)
    
    A = sigmoid(np.dot(w.T, X) + b)
    
    for i in range(A.shape[1]):
        Y_prediction[0,i] = 1 if A[0, i] > 0.5 else 0
    
    assert(Y_prediction.shape == (1,m))
    
    return Y_prediction

# %%
def model(X_train, Y_train, X_test, num_iterations=1000, learning_rate=0.5):
    #Initialize parameters with 0s
    w, b = init_zeroed(X_train.shape[0])
    
    #Gradient descent
    parameters, grads, costs = optimize(w, b, X_train, Y_train, num_iterations, learning_rate)
    
    #Retrive parameters w, b from dictionary
    w = parameters['w']
    b = parameters['b']
    
    #Predict test/train set examples
#     Y_prediction_test = predict(w, b, X_test)
    Y_prediction_train = predict(w, b, X_train)
    
    #Print test/train errors
    print("train accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_train - Y_train)) * 100))
#     print("test accuracy: {} %".format(100 - np.mean(np.abs(Y_prediction_test - Y_test)) * 100))

# %%
model(x, y, x_test)
# Out:
# <ipython-input-394-fcf915afedbf>:5: RuntimeWarning: divide by zero encountered in log
#   cost = (-1/m) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1-A)))
# <ipython-input-394-fcf915afedbf>:5: RuntimeWarning: invalid value encountered in multiply
#   cost = (-1/m) * np.sum(Y * np.log(A) + (1-Y) * (np.log(1-A)))
# train accuracy: 47.0 %

# %%
x.shape[0]
# Out:
# 100
